# %% [markdown]
# **EDA**

# %% [markdown]
# The First step in this project is to do an EDA- an Exploratory data analysis. We will use this to  examine the data and attempt to formulate a hypothesis.

# %%
#Import 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import os
import warnings

# %%
df = pd.read_csv("dataset_Facebook.csv",sep=";")

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
columns=df.columns
columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
df.shape
# Out:
# (500, 19)

# %% [markdown]
# I have used processes to allow me to be able to bring out my data and analyze and see what I am working with. I see that the shape of my data is (500,19) which tells me i have 500 rows and 19 columns. I have seen what my columns are and that most of my data are numerical and not strings.

# %%
sns.pairplot(df.iloc[:,:5])
# Out:
# /Users/oluwamayowa/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df.iloc[:5,:7])
# Out:
# /Users/oluwamayowa/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df.iloc[:7,:9])
# Out:
# /Users/oluwamayowa/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df.iloc[:9,:11])
# Out:
# /Users/oluwamayowa/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df.iloc[:11,:14])
# Out:
# /Users/oluwamayowa/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df.iloc[:14,:16])
# Out:
# /Users/oluwamayowa/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df.iloc[:16,:18])
# Out:
# /Users/oluwamayowa/anaconda3/envs/phase1/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#plot histograms
df.hist(column = ["Paid"])
df["Paid"].mean()
# Out:
# 0.2785571142284569

# %%
df.hist(column=["Post Hour"])
df["Post Hour"].mean()
# Out:
# 7.84

# %%
df.hist(column=["Post Weekday"])
df["Post Weekday"].mean()
# Out:
# 4.15

# %%
df.hist(column = ["Page total likes"])
df["Page total likes"].mean()
# Out:
# 123194.176

# %%
df.hist(column=["share"])
df["share"].mean()
# Out:
# 27.266129032258064

# %%
df.hist(column = ["Lifetime Post Impressions by people who have liked your Page"])
df["Lifetime Post Impressions by people who have liked your Page"].mean()
# Out:
# 16766.376

# %%
df.hist(column = ["Lifetime Post Total Reach"])
df["Lifetime Post Total Reach"].mean()
# Out:
# 13903.36

# %%
df.hist(column = ["like"])
df["like"].mean()
# Out:
# 177.94589178356713

# %%
df.hist(column=["Total Interactions"])
df["Total Interactions"].mean()
# Out:
# 212.12

# %%
df.hist(column=["Lifetime Post Impressions by people who have liked your Page"])
df["Lifetime Post Impressions by people who have liked your Page"].mean()
# Out:
# 16766.376

# %%
df.hist(column=["comment"])
df["comment"].mean()
# Out:
# 7.482

# %%
df.boxplot(column= ["Paid"])
df["Paid"].mean()
# Out:
# 0.2785571142284569

# %%
df.boxplot(column=["share"])
df["share"].mean()
# Out:
# 27.266129032258064

# %%
df.boxplot(column=["Post Hour"])
df["Post Hour"].mean()
# Out:
# 7.84

# %%
df.boxplot(column=["Post Weekday"])
df["Post Weekday"].mean()
# Out:
# 4.15

# %%
df.boxplot(column=["Page total likes"])
df["Page total likes"].mean()
# Out:
# 123194.176

# %%
df.boxplot(column=["Total Interactions"])
df["Total Interactions"].mean()
# Out:
# 212.12

# %%
df.boxplot(column=["Lifetime Post Impressions by people who have liked your Page"])
df["Lifetime Post Impressions by people who have liked your Page"].mean()
# Out:
# 16766.376

# %%
df.boxplot(column=["Lifetime Post Total Reach"])
df["Lifetime Post Total Reach"].mean()
# Out:
# 13903.36

# %%
df.boxplot(column=["like"])
df["like"].mean()
# Out:
# 177.94589178356713

# %%
df.boxplot(column=["comment"])
df["comment"].mean()
# Out:
# 7.482

# %%
sns.scatterplot(data=df, x= 'comment', y="like")
# Out:
# <Axes: xlabel='comment', ylabel='like'>

# %%
sns.scatterplot(data=df, x= 'like', y="share")
# Out:
# <Axes: xlabel='like', ylabel='share'>

# %%
sns.scatterplot(data=df, x= 'like', y="Total Interactions")
# Out:
# <Axes: xlabel='like', ylabel='Total Interactions'>

# %%
sns.scatterplot(data=df, x="Post Hour", y= "like")
# Out:
# <Axes: xlabel='Post Hour', ylabel='like'>

# %%
sns.scatterplot(data=df, x= 'Page total likes' , y="Lifetime Post Impressions by people who have liked your Page")
# Out:
# <Axes: xlabel='Page total likes', ylabel='Lifetime Post Impressions by people who have liked your Page'>

# %%
sns.scatterplot(data=df, x= 'Total Interactions', y="Lifetime Post Total Reach")
# Out:
# <Axes: xlabel='Total Interactions', ylabel='Lifetime Post Total Reach'>

# %%
sns.scatterplot(data=df, x = "Post Weekday", y= "like")
# Out:
# <Axes: xlabel='Post Weekday', ylabel='like'>

# %%
sns.scatterplot(data=df, x = "Post Weekday", y= "Page total likes")
# Out:
# <Axes: xlabel='Post Weekday', ylabel='Page total likes'>

# %%
sns.scatterplot(data=df, x = "Page total likes", y= "Total Interactions")
# Out:
# <Axes: xlabel='Page total likes', ylabel='Total Interactions'>

# %%
sns.scatterplot(data=df, x = "share", y= 'Page total likes')
# Out:
# <Axes: xlabel='share', ylabel='Page total likes'>

# %% [markdown]
# ## Data Cleaning Lab II
# In the next section, I will give a brief update regarding my dataset using the visualizations & output you've generated.

# %% [markdown]
# The page total like shows a left skewed distribution.The Lifetime Post Total Reach shows a right skewed distrubution meaning the majority of the data is located on the left side of the graph, and the mean, or average, is greater than the median.

# %%
df.isna()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0               False  False     False       False         False      False
# 1               False  False     False       False         False      False
# 2               False  False     False       False         False      False
# 3               False  False     False       False         False      False
# 4               False  False     False       False         False      False
# ..                ...    ...       ...         ...           ...        ...
# 495             False  False     False       False         False      False
# 496             False  False     False       False         False      False
# 497             False  False     False       False         False      False
# 498             False  False     False       False         False      False
# 499             False  False     False       False         False      False
#
# ...

# %%
df.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %% [markdown]
# These are sum of the missing columns. Our data is full and there are little missing values in Lifetime Post Total Reach , like, and share. Lifetime Post Total Reach has 1 missing value; like has 1 missing value and share has 4 missing value.

# %%
df.dropna()
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 494             85093   Photo         3           1             7         10
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
#
# ...

# %%
df.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...
